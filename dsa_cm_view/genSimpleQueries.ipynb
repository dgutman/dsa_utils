# %%
# from PIL import Image
# import requests, sqlite3,tqdm
# from io import BytesIO
# import pandas as pd

# %load_ext autoreload
# %autoreload 2
# import dashDBHelpers as hlprs

dbName = "sqliteDb/confMatrixDB.db"
import pandas as pd
import get_dataset as gds

# %%
df = gds.getConfusionMatrixData(dbName)

# %%
df.currentStain.fillna('Unk',inplace=True)

# %%
from sklearn import metrics
import plotly.figure_factory as ff

df.currentStain.fillna("Unk", inplace=True)


### Generate the confusion matrix based on the data frame that was just loaded..
lblSet = ["HE", "Tau", "Syn", "aBeta", "pTDP", "Biels"]
print(df)
print(list(df.currentStain.values))
print(df.modelLabel.values)
cm = metrics.confusion_matrix(
    list(df.currentStain.values), list(df.modelLabel.values), labels=lblSet
)
cmfig = ff.create_annotated_heatmap(cm, x=lblSet, y=lblSet, colorscale="Viridis")
# Out:
#      modelLabel         currentStain    id    modelName  \
# 0         Abeta  No Stain Identified     1  stainPredV1
# 1         Abeta  No Stain Identified     2  stainPredV1
# 2         Biels                Biels     3  stainPredV1
# 3         Biels                Biels     4  stainPredV1
# 4          Ptdp                aBeta     5  stainPredV1
# ...         ...                  ...   ...          ...
# 1226         He                   HE  1227  stainPredV1
# 1227         He                   HE  1228  stainPredV1
# 1228         He                   HE  1229  stainPredV1
# 1229         He                   HE  1230  stainPredV1
# 1230         He                   HE  1231  stainPredV1
#
#                        imageId  \
# 0     6105948c68f4fe34fca1bf7c
# 1     6105948c68f4fe34fca1bf7f
# 2     6105948c68f4fe34fca1bf82
# 3     6105948d68f4fe34fca1bf85
# 4     6105948d68f4fe34fca1bf88
# ...                        ...
# 1226  6105968268f4fe34fca1cdf8
# ...

# %%
lblSet
# len(df.currentStain)
#len(df.modelLabel)
# Out:
# ['HE', 'Tau', 'Syn', 'aBeta', 'pTDP', 'Biels']

# %%
# Out:
# 1231

# %%
# con = sqlite3.connect(dbName)
# con.row_factory = hlprs.dict_factory
# c = con.cursor()


# # c.execute("PRAGMA table_info('modelResponses');")
# c.execute('select modelLabel, "meta.npSchema.stainID" as currentStain, *  from modelResponses m left join dsai on "_id"=imageId')
# mr_df = pd.DataFrame(c.fetchall())
# con.close()

# mr_df
# Out:
#      modelLabel         currentStain    id    modelName  \
# 0         Abeta  No Stain Identified     1  stainPredV1
# 1         Abeta  No Stain Identified     2  stainPredV1
# 2         Biels                Biels     3  stainPredV1
# 3         Biels                Biels     4  stainPredV1
# 4          Ptdp                aBeta     5  stainPredV1
# ...         ...                  ...   ...          ...
# 1226         He                   HE  1227  stainPredV1
# 1227         He                   HE  1228  stainPredV1
# 1228         He                   HE  1229  stainPredV1
# 1229         He                   HE  1230  stainPredV1
# 1230         He                   HE  1231  stainPredV1
#
#                        imageId  \
# 0     6105948c68f4fe34fca1bf7c
# 1     6105948c68f4fe34fca1bf7f
# 2     6105948c68f4fe34fca1bf82
# 3     6105948d68f4fe34fca1bf85
# 4     6105948d68f4fe34fca1bf88
# ...                        ...
# 1226  6105968268f4fe34fca1cdf8
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 from dash import data_table
#
# ModuleNotFoundError: No module named 'dash'
